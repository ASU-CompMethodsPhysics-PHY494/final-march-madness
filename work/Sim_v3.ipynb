# %%
import numpy as np

# %%
# Array of South, West, East and Midwest Regionals respectively, listed in the following seed ranking order (to match round 1 game matchup order) #1, 16, 8, 9, 5, 12, 4, 13, 6, 11, 3, 14, 7, 10, 2, 15
R1teams = (("Kansas", "Austin Peay", "Colorado", "Connecticut", "Maryland", "South Dakota State", "California", "Hawaii", "Arizona", "Wichita State", "Miami", "Buffalo", "Iowa", "Temple", "Villanova", "UNC Asheville"),
            ("Oregon", "Holy Cross", "Saint Joseph's", "Cincinnatti", "Baylor", "Yale", "Duke", "UNC Wilmington", "Texas", "Northern Iowa", "Texan A&M", "Green Bay", "Oregon State", "VCU", "Oklahoma", "Cal State Bakersfield"),
            ("North Carolina", "Florida Gulf Coast", "USC", "Providence", "Indiana", "Chattanooga", "Kentucky", "Stony Brook", "Notre Dame", "Michigan", "West Virginia", "Stephen F Austin", "Wisconsin", "Pittsburgh", "Xavier", "Weber State"), 
            ("Virginia", "Hampton", "Texas Tech", "Butler", "Purdue", "Ankansas-Little Rock", "Iowa State", "Iona", "Seton Hall", "Gonzaga", "Utah", "Fresno State", "Dayton", "Syracuse", "Michigan State", "Middle Tennessee"))

# %%
Champions = []

# %%
for i in range(1000):

    # blank placeholder for each round winners
    R1Winners=[["", "", "", "", "", "", "", ""],
              ["", "", "", "", "", "", "", ""],
              ["", "", "", "", "", "", "", ""],
              ["", "", "", "", "", "", "", ""]]

    R2Winners=[["", "", "", ""],
              ["", "", "", ""],
              ["", "", "", ""],
              ["", "", "", ""]]

    R3Winners=[["", ""],
              ["", ""],
              ["", ""],
              ["", ""]]

    R4Winners=[[""],
              [""],
              [""],
              [""]]

    R5Winners=["", ""]

    Champion=[""]

    #Random number generator for first round of games (8 games x 4 conferences)
    Rand1 = np.random.randint(100, size=(4, 8))

    # Round 1 simulation
    for i in range(8):
        for j in range(4):
            if Rand1[j][i] > 49:
                R1Winners[j][i] = R1teams[j][2*i]
            else:
                R1Winners[j][i] = R1teams[j][2*i+1]

    Rand2 = np.random.randint(100, size=(4, 4))  #Random generator for second round (4 games x 4 conferences)

    # Round 2 simulation
    for i in range(4):
        for j in range(4):
            if Rand2[j][i] > 49:
                R2Winners[j][i] = R1Winners[j][2*i]
            else:
                R2Winners[j][i] = R1Winners[j][2*i+1]

    Rand3 = np.random.randint(100, size=(4, 2))

    # Round 3 (Sweet 16) simulation 
    for i in range(2):
        for j in range(4):
            if Rand3[j][i] > 49:
                R3Winners[j][i] = R2Winners[j][2*i]
            else:
                R3Winners[j][i] = R2Winners[j][2*i+1]

    Rand4 = np.random.randint(100, size=(4, 1))

    # Round 4 (Elite 8) simulation 
    for i in range(1):
        for j in range(4):
            if Rand4[j][i] > 49:
                R4Winners[j][i] = R3Winners[j][2*i]
            else:
                R4Winners[j][i] = R3Winners[j][2*i+1]

    Rand5 = np.random.randint(100, size=(2, 1))

    # Round 5 (Final 4) simulation 
    for i in range(2):
        if Rand5[i][0] > 49:
            R5Winners[i] = R4Winners[2*i][0]
        else:
            R5Winners[i] = R4Winners[2*i+1][0]

    Rand6 = np.random.randint(100, size=(1, 1))

    # Round 6 (Championship) simulation 

    if Rand6[0][0] > 49:
        Champion = R5Winners[0]
    else:
        Champion = R5Winners[1]
    
    Champions.append(Champion)

# %%
Champions
# Out:
# ['Ankansas-Little Rock',
#  'South Dakota State',
#  'Michigan State',
#  'Austin Peay',
#  'Texas',
#  'VCU',
#  'Cal State Bakersfield',
#  'Wisconsin',
#  'Notre Dame',
#  'Hampton',
#  'Arizona',
#  'Oklahoma',
#  'USC',
#  'Middle Tennessee',
#  'Kansas',
#  'Oregon State',
#  'Weber State',
#  'Purdue',
#  'Villanova',
#  'Austin Peay',
#  'Yale',
#  'Oregon State',
#  'Michigan',
#  'Purdue',
#  'Yale',
#  'Texas Tech',
#  'Iona',
#  'South Dakota State',
#  'Texan A&M',
#  'Kansas',
#  'VCU',
#  'Syracuse',
#  'Hampton',
#  'Michigan State',
#  'Purdue',
#  'Baylor',
#  'Purdue',
#  'Utah',
#  'West Virginia',
#  'Weber State',
#  'Providence',
#  'Virginia',
#  'Texan A&M',
#  'Purdue',
#  'South Dakota State',
#  'Virginia',
#  'Notre Dame',
#  'California',
#  'Utah',
#  'Wisconsin',
#  'Seton Hall',
#  'Holy Cross',
#  'Temple',
#  'California',
#  "Saint Joseph's",
#  'Wisconsin',
#  'Texas Tech',
#  'Duke',
#  'Iowa State',
#  'Seton Hall',
#  'Michigan',
#  'Indiana',
#  'West Virginia',
#  'UNC Asheville',
#  'North Carolina',
#  'Cincinnatti',
#  'Cal State Bakersfield',
#  'VCU',
#  'Wichita State',
#  'Wisconsin',
#  "Saint Joseph's",
#  'West Virginia',
#  'Utah',
#  'Stephen F Austin',
#  'North Carolina',
#  'Oregon',
#  'Michigan State',
#  'Green Bay',
#  'Kentucky',
#  'Pittsburgh',
#  'Indiana',
#  'Seton Hall',
#  'Ankansas-Little Rock',
#  'Seton Hall',
#  'Connecticut',
#  'Pittsburgh',
#  'Virginia',
#  'Duke',
#  'Syracuse',
#  'Holy Cross',
#  'South Dakota State',
#  'Colorado',
#  'North Carolina',
#  'North Carolina',
#  'Green Bay',
#  'Butler',
#  'Wisconsin',
#  'Fresno State',
#  'Texan A&M',
#  'Kansas',
#  'Syracuse',
#  'Arizona',
#  'Texas Tech',
#  'Temple',
#  'Miami',
#  'Hawaii',
#  'Purdue',
#  'Miami',
#  'Wichita State',
#  'Xavier',
#  'Buffalo',
#  'Butler',
#  'Hampton',
#  'Hawaii',
#  'UNC Asheville',
#  'Seton Hall',
#  'VCU',
#  'Connecticut',
#  'Buffalo',
#  'Dayton',
#  'West Virginia',
#  'Oregon',
#  'Oregon',
#  'Michigan',
#  'Connecticut',
#  'USC',
#  'Texas Tech',
#  'Texas Tech',
#  'Providence',
#  'Purdue',
#  'Stephen F Austin',
#  'Villanova',
#  'Connecticut',
#  'Green Bay',
#  'Iowa',
#  'Florida Gulf Coast',
#  'Yale',
#  'Iona',
#  'Notre Dame',
#  'Arizona',
#  'Wisconsin',
#  'Virginia',
#  'Michigan',
#  'Texas',
#  'Connecticut',
#  'Iowa',
#  'Cal State Bakersfield',
#  'Connecticut',
#  'Yale',
#  'Indiana',
#  'UNC Wilmington',
#  'Duke',
#  'Ankansas-Little Rock',
#  'UNC Wilmington',
#  'Connecticut',
#  'Cal State Bakersfield',
#  'Purdue',
#  'Colorado',
#  'Fresno State',
#  'UNC Wilmington',
#  'Yale',
#  'Stony Brook',
#  'Seton Hall',
#  'Chattanooga',
#  'Temple',
#  'South Dakota State',
#  'Iona',
#  'Middle Tennessee',
#  'Syracuse',
#  'Gonzaga',
#  'Hampton',
#  'USC',
#  'USC',
#  'Middle Tennessee',
#  'Stony Brook',
#  'Cal State Bakersfield',
#  'Hampton',
#  'Arizona',
#  'Michigan',
#  'Oregon',
#  'Arizona',
#  'Purdue',
#  'Gonzaga',
#  'Iona',
#  'Hawaii',
#  'Iona',
#  'Xavier',
#  'Michigan',
#  'Hampton',
#  'West Virginia',
#  'Green Bay',
#  'USC',
#  'Gonzaga',
#  'Yale',
#  'Temple',
#  'Michigan State',
#  'Northern Iowa',
#  'Indiana',
#  'Weber State',
#  'South Dakota State',
#  'North Carolina',
#  'Wichita State',
#  'Texas',
#  'VCU',
#  'Wichita State',
#  'Wichita State',
#  'Syracuse',
#  'Michigan State',
#  'Dayton',
#  'Northern Iowa',
#  'Duke',
#  'North Carolina',
#  'Dayton',
#  'VCU',
#  'Stony Brook',
#  'California',
#  'Texas',
#  'Seton Hall',
#  'Iowa State',
#  'Cal State Bakersfield',
#  'Connecticut',
#  'Duke',
#  'Stephen F Austin',
#  'West Virginia',
#  "Saint Joseph's",
#  'Utah',
#  'Xavier',
#  'Cincinnatti',
#  'Weber State',
#  'Syracuse',
#  'Hawaii',
#  'Villanova',
#  'Dayton',
#  'Virginia',
#  'Oregon State',
#  'Xavier',
#  'Green Bay',
#  'Virginia',
#  'Notre Dame',
#  'Seton Hall',
#  'South Dakota State',
#  'Baylor',
#  'Utah',
#  'Virginia',
#  'Connecticut',
#  'Iowa State',
#  'Villanova',
#  'Cal State Bakersfield',
#  'Michigan State',
#  'Weber State',
#  'UNC Asheville',
#  'Xavier',
#  'Kansas',
#  'Providence',
#  'Northern Iowa',
#  'Florida Gulf Coast',
#  'Xavier',
#  'Purdue',
#  'Green Bay',
#  'Dayton',
#  'Austin Peay',
#  'Texas Tech',
#  'Middle Tennessee',
#  'Pittsburgh',
#  'UNC Asheville',
#  'Michigan',
#  'North Carolina',
#  'VCU',
#  'Chattanooga',
#  'Arizona',
#  'Texas',
#  'Duke',
#  'Connecticut',
#  'Stephen F Austin',
#  'Butler',
#  'USC',
#  'Baylor',
#  'Michigan State',
#  'Texan A&M',
#  'Duke',
#  'Cal State Bakersfield',
#  'Notre Dame',
#  'Arizona',
#  'Texas Tech',
#  'Fresno State',
#  'Oregon State',
#  'Buffalo',
#  'Iowa State',
#  'Seton Hall',
#  'Duke',
#  'Purdue',
#  'Weber State',
#  'Gonzaga',
#  'Weber State',
#  'Weber State',
#  'Ankansas-Little Rock',
#  'Butler',
#  'West Virginia',
#  'Gonzaga',
#  'Iowa',
#  'USC',
#  'Gonzaga',
#  'Weber State',
#  'Buffalo',
#  'UNC Wilmington',
#  'Green Bay',
#  'Kentucky',
#  'Stony Brook',
#  'Dayton',
#  'Providence',
#  'Michigan',
#  'Utah',
#  'North Carolina',
#  'Colorado',
#  'Arizona',
#  'Yale',
#  'Iowa',
#  'Iona',
#  'Seton Hall',
#  'USC',
#  'Utah',
#  'Fresno State',
#  'Fresno State',
#  'Dayton',
#  "Saint Joseph's",
#  'Cal State Bakersfield',
#  'Miami',
#  'Austin Peay',
#  'Seton Hall',
#  'Iowa',
#  'Austin Peay',
#  'Colorado',
#  'Temple',
#  'Chattanooga',
#  'Connecticut',
#  'Hampton',
#  'Butler',
#  'Texan A&M',
#  'Michigan',
#  'North Carolina',
#  'VCU',
#  'Michigan State',
#  'Austin Peay',
#  'West Virginia',
#  'Hampton',
#  'Yale',
#  'Gonzaga',
#  'Syracuse',
#  'Wisconsin',
#  'Dayton',
#  'Providence',
#  'West Virginia',
#  'Arizona',
#  'Hawaii',
#  'Notre Dame',
#  'Connecticut',
#  'Hampton',
#  'Iowa State',
#  'Weber State',
#  'Ankansas-Little Rock',
#  'West Virginia',
#  'Wichita State',
#  'Temple',
#  'UNC Asheville',
#  'Hawaii',
#  'Cal State Bakersfield',
#  'Texan A&M',
#  'Northern Iowa',
#  'Holy Cross',
#  'Northern Iowa',
#  'Duke',
#  'Maryland',
#  'Pittsburgh',
#  'Arizona',
#  'Florida Gulf Coast',
#  'Colorado',
#  'Kansas',
#  'Kentucky',
#  'Weber State',
#  'Kentucky',
#  'Miami',
#  'Texan A&M',
#  'Xavier',
#  'Xavier',
#  'Weber State',
#  'Texas',
#  'Maryland',
#  'Baylor',
#  'Seton Hall',
#  'Texan A&M',
#  'Villanova',
#  'Connecticut',
#  'Utah',
#  'Texan A&M',
#  'Duke',
#  'Purdue',
#  'Ankansas-Little Rock',
#  'Kansas',
#  "Saint Joseph's",
#  'Yale',
#  'Iowa',
#  'North Carolina',
#  'Hawaii',
#  'Oregon',
#  'Baylor',
#  'Michigan',
#  'Texas Tech',
#  'Weber State',
#  'Stephen F Austin',
#  'VCU',
#  'USC',
#  'Stony Brook',
#  'Utah',
#  'Ankansas-Little Rock',
#  'Iona',
#  'Texan A&M',
#  'UNC Asheville',
#  'Ankansas-Little Rock',
#  'Wichita State',
#  'Iowa',
#  'Miami',
#  'California',
#  'Miami',
#  'Syracuse',
#  'Virginia',
#  'Maryland',
#  'Hampton',
#  'Chattanooga',
#  'Kentucky',
#  'Xavier',
#  'Oregon',
#  'Notre Dame',
#  "Saint Joseph's",
#  'Syracuse',
#  'Wichita State',
#  'Temple',
#  'Purdue',
#  'Iowa State',
#  'UNC Wilmington',
#  'Purdue',
#  'Michigan',
#  'Oregon State',
#  'South Dakota State',
#  'Buffalo',
#  'Dayton',
#  'Oregon State',
#  'UNC Asheville',
#  'Wichita State',
#  'Michigan State',
#  'Villanova',
#  'Iowa',
#  'Weber State',
#  'Wisconsin',
#  'Wisconsin',
#  'Virginia',
#  'Weber State',
#  "Saint Joseph's",
#  'Northern Iowa',
#  'Seton Hall',
#  'Texas',
#  'Oklahoma',
#  'Florida Gulf Coast',
#  'Stony Brook',
#  'Arizona',
#  'Duke',
#  'Green Bay',
#  'Iowa',
#  'Colorado',
#  'Iona',
#  'Miami',
#  'Stony Brook',
#  'Indiana',
#  'Wichita State',
#  'Iona',
#  'Cal State Bakersfield',
#  'Cal State Bakersfield',
#  'Butler',
#  "Saint Joseph's",
#  'Ankansas-Little Rock',
#  'Green Bay',
#  'Pittsburgh',
#  'Syracuse',
#  'Pittsburgh',
#  'Oregon',
#  'Austin Peay',
#  'Ankansas-Little Rock',
#  'Yale',
#  'Miami',
#  'USC',
#  'Cincinnatti',
#  'Ankansas-Little Rock',
#  'Michigan State',
#  'West Virginia',
#  'Oregon',
#  'Weber State',
#  'Northern Iowa',
#  'Miami',
#  'Texas',
#  'Syracuse',
#  'Hampton',
#  'Texas Tech',
#  'Baylor',
#  'Texas Tech',
#  'Providence',
#  'Wichita State',
#  'Stony Brook',
#  'Seton Hall',
#  'Providence',
#  'Ankansas-Little Rock',
#  'Iona',
#  'West Virginia',
#  'Connecticut',
#  'Hawaii',
#  'Utah',
#  'Ankansas-Little Rock',
#  'Oregon',
#  'Butler',
#  'Hampton',
#  'Weber State',
#  'Texas',
#  'Utah',
#  'Dayton',
#  'Middle Tennessee',
#  'Fresno State',
#  'Hawaii',
#  'Xavier',
#  'Temple',
#  'UNC Wilmington',
#  'Holy Cross',
#  'Pittsburgh',
#  'Buffalo',
#  'Syracuse',
#  'Butler',
#  'Syracuse',
#  'Chattanooga',
#  'Wichita State',
#  'Indiana',
#  'Stephen F Austin',
#  'Duke',
#  'Connecticut',
#  'Iowa State',
#  'Holy Cross',
#  'Arizona',
#  'Oregon',
#  'Arizona',
#  'UNC Wilmington',
#  'Cincinnatti',
#  'Arizona',
#  'Northern Iowa',
#  'Iona',
#  'Stony Brook',
#  'North Carolina',
#  'Oklahoma',
#  'UNC Wilmington',
#  'Kentucky',
#  'Xavier',
#  'Wisconsin',
#  'Providence',
#  'Hawaii',
#  'Providence',
#  'Yale',
#  'Connecticut',
#  'Ankansas-Little Rock',
#  'Duke',
#  'Texas',
#  'Weber State',
#  'Iowa',
#  'Providence',
#  'Michigan',
#  'Gonzaga',
#  "Saint Joseph's",
#  'Stony Brook',
#  'Purdue',
#  "Saint Joseph's",
#  'VCU',
#  'Maryland',
#  'Michigan',
#  'Utah',
#  "Saint Joseph's",
#  'Texas Tech',
#  'UNC Wilmington',
#  'Butler',
#  'Indiana',
#  'Baylor',
#  'Weber State',
#  'Providence',
#  'Texas Tech',
#  'Chattanooga',
#  'Purdue',
#  'Pittsburgh',
#  'Utah',
#  'Temple',
#  'Michigan State',
#  'Cal State Bakersfield',
#  'South Dakota State',
#  'Duke',
#  'Texas',
#  'Pittsburgh',
#  'Seton Hall',
#  'Syracuse',
#  'Yale',
#  'Baylor',
#  'Utah',
#  'Weber State',
#  'Stony Brook',
#  'West Virginia',
#  'Chattanooga',
#  'Austin Peay',
#  'Texan A&M',
#  'Buffalo',
#  'Cal State Bakersfield',
#  'Oregon State',
#  'California',
#  'Michigan State',
#  'Syracuse',
#  'Michigan State',
#  'Wisconsin',
#  'Kansas',
#  'Texas',
#  'Baylor',
#  'Michigan State',
#  'Utah',
#  'Cal State Bakersfield',
#  'Xavier',
#  'Baylor',
#  'Florida Gulf Coast',
#  'Florida Gulf Coast',
#  'Holy Cross',
#  'Providence',
#  'VCU',
#  'Oklahoma',
#  'Maryland',
#  'Stephen F Austin',
#  'Pittsburgh',
#  'Iona',
#  'Chattanooga',
#  'Austin Peay',
#  'Green Bay',
#  'USC',
#  'Kentucky',
#  'Northern Iowa',
#  'Holy Cross',
#  'Michigan',
#  'Indiana',
#  'Dayton',
#  'Oregon',
#  'Kansas',
#  'Wichita State',
#  'Villanova',
#  'Weber State',
#  'Syracuse',
#  'Oklahoma',
#  'Hawaii',
#  "Saint Joseph's",
#  'Oklahoma',
#  'North Carolina',
#  'Wichita State',
#  'Hawaii',
#  'Texas',
#  'Cal State Bakersfield',
#  'Butler',
#  'Villanova',
#  'West Virginia',
#  'Oklahoma',
#  'Gonzaga',
#  'Texan A&M',
#  'Temple',
#  'Notre Dame',
#  'Virginia',
#  'Oregon',
#  'UNC Wilmington',
#  'Miami',
#  'Texas',
#  'Hampton',
#  'Cal State Bakersfield',
#  'Texan A&M',
#  'VCU',
#  'Northern Iowa',
#  'Duke',
#  'Michigan State',
#  'Iowa',
#  'Kentucky',
#  'Yale',
#  'Ankansas-Little Rock',
#  'Utah',
#  'VCU',
#  'Fresno State',
#  'Stephen F Austin',
#  'Connecticut',
#  'Syracuse',
#  'Oregon',
#  'Baylor',
#  'UNC Asheville',
#  'Indiana',
#  'Utah',
#  'Indiana',
#  'Utah',
#  'Kentucky',
#  'Seton Hall',
#  'Temple',
#  'Baylor',
#  'Oregon State',
#  'Duke',
#  'Maryland',
#  'West Virginia',
#  'Purdue',
#  'Cal State Bakersfield',
#  'Arizona',
#  'Texan A&M',
#  'Miami',
#  'Dayton',
#  'Hampton',
#  'Butler',
#  'Syracuse',
#  'Texas',
#  'Providence',
#  'Cal State Bakersfield',
#  'USC',
#  'Purdue',
#  'Utah',
#  'USC',
#  'Oregon',
#  'Providence',
#  'Kansas',
#  'Temple',
#  'Virginia',
#  'Utah',
#  'Notre Dame',
#  'Hawaii',
#  'Cincinnatti',
#  'Texan A&M',
#  'Chattanooga',
#  'Virginia',
#  'Northern Iowa',
#  'Hawaii',
#  'Gonzaga',
#  'Baylor',
#  'Notre Dame',
#  'North Carolina',
#  'Stony Brook',
#  'Colorado',
#  'Michigan State',
#  'Maryland',
#  'Buffalo',
#  'Hawaii',
#  'South Dakota State',
#  'Virginia',
#  'Villanova',
#  'Fresno State',
#  'Kansas',
#  'Arizona',
#  'Seton Hall',
#  'Arizona',
#  'Iona',
#  'Kentucky',
#  'UNC Asheville',
#  'Texas',
#  'Syracuse',
#  'Fresno State',
#  'Dayton',
#  'Texas',
#  'Northern Iowa',
#  'Miami',
#  'Cincinnatti',
#  'Purdue',
#  'Oregon',
#  'Notre Dame',
#  'Stephen F Austin',
#  'Wichita State',
#  'Cal State Bakersfield',
#  'Maryland',
#  'VCU',
#  "Saint Joseph's",
#  'UNC Asheville',
#  'Temple',
#  'Yale',
#  'Holy Cross',
#  'Pittsburgh',
#  'Baylor',
#  'Kentucky',
#  'Fresno State',
#  'Iowa',
#  'Providence',
#  'Pittsburgh',
#  'Providence',
#  'Texas Tech',
#  'Duke',
#  'Providence',
#  'VCU',
#  'Utah',
#  'Connecticut',
#  'Indiana',
#  'Duke',
#  'Middle Tennessee',
#  'USC',
#  'Miami',
#  'Middle Tennessee',
#  'VCU',
#  'Kentucky',
#  'Holy Cross',
#  'Oklahoma',
#  'Pittsburgh',
#  'Buffalo',
#  'Hawaii',
#  'Miami',
#  'Virginia',
#  'USC',
#  'Kentucky',
#  'Cal State Bakersfield',
#  'Iowa',
#  'Temple',
#  'Dayton',
#  'Arizona',
#  'Northern Iowa',
#  'Wisconsin',
#  'Seton Hall',
#  'Michigan',
#  'Oregon State',
#  'USC',
#  'Hampton',
#  'Providence',
#  'Butler',
#  'Northern Iowa',
#  'Texas',
#  'Purdue',
#  'Austin Peay',
#  'Colorado',
#  'Oregon State',
#  'Chattanooga',
#  'UNC Asheville',
#  'Oregon State',
#  'Green Bay',
#  'Pittsburgh',
#  'Michigan State',
#  'Stony Brook',
#  'West Virginia',
#  'South Dakota State',
#  'Middle Tennessee',
#  "Saint Joseph's",
#  'Michigan',
#  'Texan A&M',
#  'Weber State',
#  'Virginia',
#  'Iona',
#  'Miami',
#  'Kansas',
#  'Virginia',
#  'Stony Brook',
#  'Oklahoma',
#  'Baylor',
#  "Saint Joseph's",
#  'Iowa',
#  'Seton Hall',
#  'Duke',
#  'Florida Gulf Coast',
#  'VCU',
#  'Texan A&M',
#  'Notre Dame',
#  'Butler',
#  'Austin Peay',
#  'Indiana',
#  'Iowa State',
#  'Gonzaga',
#  'VCU',
#  'Notre Dame',
#  'Colorado',
#  'Providence',
#  'USC',
#  'VCU',
#  'Kentucky',
#  'Duke',
#  'Holy Cross',
#  'Middle Tennessee',
#  'Maryland',
#  'Dayton',
#  'Weber State',
#  'Wisconsin',
#  'Chattanooga',
#  'Colorado',
#  'Pittsburgh',
#  'Kansas',
#  'Texan A&M',
#  'Michigan State',
#  'Oregon',
#  'Butler',
#  'Providence',
#  'UNC Wilmington',
#  'Green Bay',
#  "Saint Joseph's",
#  'Florida Gulf Coast',
#  'Xavier',
#  'Texas',
#  'Ankansas-Little Rock',
#  'Syracuse',
#  'Hampton',
#  'Connecticut',
#  'Notre Dame',
#  'North Carolina',
#  'USC',
#  'UNC Wilmington',
#  'Butler',
#  'Utah',
#  'Florida Gulf Coast',
#  'California',
#  'Oregon State',
#  'Temple',
#  'Temple',
#  'Iowa',
#  'Texas',
#  'Xavier',
#  'Temple',
#  'Xavier',
#  'Oregon',
#  'Duke',
#  'Baylor',
#  'Stephen F Austin',
#  'Providence',
#  'Providence',
#  'Florida Gulf Coast',
#  'California',
#  'Texas Tech',
#  'Colorado',
#  'Pittsburgh',
#  'Oklahoma',
#  "Saint Joseph's",
#  'Cincinnatti',
#  'Seton Hall',
#  'Syracuse',
#  'Duke',
#  'Dayton',
#  'Seton Hall',
#  'VCU',
#  'Weber State',
#  'Hawaii',
#  'Temple',
#  'Notre Dame',
#  'West Virginia',
#  'Ankansas-Little Rock',
#  'Duke',
#  'Iowa',
#  'Virginia',
#  'UNC Wilmington',
#  'Kansas',
#  'Ankansas-Little Rock',
#  'Utah',
#  'Baylor',
#  'Wisconsin',
#  'Yale',
#  'Texas Tech',
#  'USC',
#  'VCU',
#  'Florida Gulf Coast',
#  'Michigan',
#  'Kentucky',
#  'West Virginia',
#  'Florida Gulf Coast',
#  'Iowa',
#  'Buffalo',
#  'Syracuse',
#  'Kentucky',
#  'Hawaii',
#  'Oregon',
#  'Wichita State',
#  'Temple',
#  'Maryland',
#  'Cal State Bakersfield',
#  'Virginia',
#  'Ankansas-Little Rock',
#  'Virginia',
#  'Pittsburgh',
#  'Syracuse',
#  'Holy Cross',
#  'Iona',
#  'Villanova',
#  'West Virginia',
#  'Fresno State',
#  'Butler',
#  'Hawaii',
#  'Buffalo',
#  'West Virginia',
#  'Michigan State',
#  'Duke',
#  "Saint Joseph's",
#  'Dayton',
#  'Stony Brook',
#  'Notre Dame',
#  'UNC Wilmington',
#  'Yale',
#  'Indiana',
#  'Holy Cross',
#  'Iona',
#  'Oklahoma',
#  'Pittsburgh',
#  'Chattanooga',
#  'Notre Dame',
#  'Texas',
#  'Colorado',
#  'Michigan',
#  'Maryland',
#  'Texas Tech']

# %%
len(Champions)
# Out:
# 1000

# %%
from collections import Counter

# %%
#List most recurring Champions in list

Counter(Champions).most_common(10)
# Out:
# [('Duke', 24),
#  ('Weber State', 24),
#  ('Syracuse', 23),
#  ('Utah', 23),
#  ('Cal State Bakersfield', 22),
#  ('Providence', 22),
#  ('VCU', 21),
#  ('Texas', 21),
#  ('Seton Hall', 21),
#  ('West Virginia', 20)]

# %%
# Counts number of time the real world 2016 NCAA champion appears in our champions list

Champions.count("Villanova")
# Out:
# 10
